# %%
import matplotlib.pyplot as plt
from IPython.display import display, Image

# %%
num = [1, 2, 10, 20, 30, 100, 200]
for i in range(len(num)):
    ima = './results/VAE/VAE_sample_{}.png'.format(num[i])
    i = Image(filename=ima)
    display(i)
